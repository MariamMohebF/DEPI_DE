# %%
print ("my name is DEPI")
# Out:
# my name is DEPI

# %%
x = 30

print ("my age is: ",x)
# Out:
# my age is:  30

# %%
x = 30
type(x)
# Out:
# int

# %%
# naming convencion

# %%
my = "ana"
name = "mariam"
print (my, name)
print ("my, name")
# Out:
# ana mariam
# my, name

# %%
x,y = 10, 20
print("value of x is ",x, "value of y is ",y)
# Out:
# value of x is  10 value of y is  20

# %%
print ("Hello World")
print ("amit learning")
# Out:
# Hello World
# amit learning

# %%
#object of class
x = "mariam"
type(x)
print(type(x))
# x.
# Out:
# <class 'int'>

# %%
# format 1
x=2
y=3
print ("the value of x is  " ,x, "the value of y is ",y )
# Out:
# the value of x is   2 the value of y is  3

# %%
# format 2
print ("value of x is {} and value  of y is {}".format(x,y))
# Out:
# value of x is 2 and value  of y is 3

# %%
#format 3
print (f"the value of x is {x}, and the value of the y is {y}")
# Out:
# the value of x is 2, and the value of the y is 3

# %%
#small application
name = "Mariam Moheb"
courseName = "Data Engineering"
id = "1234567890"
print(f"My name is {name} and my course name i take is {courseName}, id is {id}")
# Out:
# My name is Mariam Moheb and my course name i take is Data Engineering, id is 1234567890

# %%
approved = True
print(type(approved))
# Out:
# <class 'bool'>

# %%
name = "welcome into data engineer course"
name[12:17]
print(type(name))
print(name[2:10])
print(name[2:10:2])
# Out:
# <class 'str'>
# lcome in
# loei

# %%
name = "welcome into data engineer course"
print(type(name))
# str - Left click - go to definition
cap = name.upper()
print(cap)
low = cap.lower()
print(low)
rep = name.replace("data", "mariam")
print(rep)
print(name.capitalize())
print(name.title())
# Out:
# <class 'str'>
# WELCOME INTO DATA ENGINEER COURSE
# welcome into data engineer course
# welcome into mariam engineer course
# Welcome into data engineer course
# Welcome Into Data Engineer Course
